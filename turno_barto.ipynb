# %% [markdown]
# <a href="https://colab.research.google.com/github/RubenArielArguello-ai/app-turnos-peluqueria/blob/main/turno_barto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install supabase
from supabase import create_client, Client
import pandas as pd

# Configura tus credenciales de Supabase
SUPABASE_URL = "https://jofwgwxicszvpfhrphoh.supabase.co"
SUPABASE_KEY = "sb_publishable_FPy1xS8bRcqSd6Y6Fs9LiA_YpoqKtMl"

# Inicializar el cliente de Supabase
#supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# 1. Traemos los datos de la tabla de turnos (reemplaza 'turnos' por el nombre exacto de tu tabla)
respuesta_turnos = supabase.table('turnos').select('*').execute()
df_turnos = pd.DataFrame(respuesta_turnos.data)

# 2. Traemos los datos de la tabla de clientes (reemplaza 'clientes' por el nombre exacto de tu tabla)
#respuesta_clientes = supabase.table('clientes').select('*').execute()
#df_clientes = pd.DataFrame(respuesta_clientes.data)

print("¡Datos descargados con éxito!")
print("Columnas en turnos:", df_turnos.columns.tolist())
#print("Columnas en clientes:", df_clientes.columns.tolist())
# Out:
# ...
# ¡Datos descargados con éxito!
# Columnas en turnos: ['id', 'created_at', 'nombre', 'telefono', 'fecha', 'hora']

# %%
PROJECT_NAME = "turnos_barto"
print("conectado el proyecto:", PROJECT_NAME)
# Out:
# conectado el proyecto: turnos_barto

# %%
# Librerías esenciales
import pandas as pd
import numpy as np

# Machine Learning clásico
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Deep Learning con TensorFlow/Keras
import tensorflow as tf
from tensorflow import keras
